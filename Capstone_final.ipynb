# %% [markdown]
# # Coursera Capstone Notebook: Clustering of Rome Subway stations

# %% [markdown]
# ## Introduction
# The Rome Metro (Metropolitana di Roma) started operation in 1955. It has three lines: A (orange), B (blue) and C (green). It has 73 stations, the length of it is about 60 km. The lines A and B intersect at Termini Station, which is also the main train station in Rome. Annually it serves for 279 million of people (2012).
# We want to look at the areas surrounding metro stations and cluster them. The areas in the historical center of Rome have a lot of touristic attractions (Vatican, Colosseum, Trevi Fountain, Spanish Steps) and hotels. Some neighborhoods are in residential areas, other in commercial. The venues near to the station determine how people use it.
# Analysis of data can show the primary purpose of the station. This data is useful for commercial business (location to open a new business), for local government (can help them in city planning), and for subway development in the future (where open new stations).

# %%
import pandas as pd
import requests
# !pip install folium
import folium # map rendering library
from bs4 import BeautifulSoup
import html5lib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# Requirement already satisfied: folium in /opt/conda/envs/Python36/lib/python3.6/site-packages (0.11.0)
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (0.4.1)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2020.4.5.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)

# %% [markdown]
# ## Data

# %%
#get list of station from Wikipedia, create dataframe from it
#https://beenje.github.io/blog/posts/parsing-html-tables-in-python-with-pandas/
res = requests.get("https://it.wikipedia.org/wiki/Stazioni_della_metropolitana_di_Roma")
#if you don't have 'lxml' parser use default: 'html.parser'
soup = BeautifulSoup(res.content,'lxml')
table = soup.find_all('table')[0] 
df_stations = pd.read_html(str(table), header=0)

#create dataframe
df_stations = df_stations[0]

#drop rows Borough == Not assigned
#df_stations = df_stations[df_stations.Borough != 'Not assigned']

# Select all duplicate rows based on Postal code
#duplicateRowsDF = df[df.duplicated(['Postal code'])]
#duplicateRowsDF

# replace / to ,
#df = df.replace(to_replace=r'\s/', value=',', regex=True)

#drop columns Interscambi and Note
df_stations.drop(columns=['Linea', 'Comune', 'Municipio', 'Interscambi', 'Note'], inplace=True)

#rename column titles to English
df_stations.rename(columns={"Stazione": "Station", "Data apertura": "Opened", "Tipologia": "Type"}, inplace=True)

#save dataframe to csv file for easy access
df_stations.to_csv('Stations_wiki.csv')

df_stations.head(5)

# %%
#read our saved csv file and convert it to dataframe
# !wget -O 'Stations_wiki.csv' https://raw.githubusercontent.com/riccione/Coursera_Capstone/master/Stations_wiki.csv
# Out:
# --2020-05-12 23:32:37--  https://raw.githubusercontent.com/riccione/Coursera_Capstone/master/Stations_wiki.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.48.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.48.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3415 (3.3K) [text/plain]
# Saving to: ‘Stations_wiki.csv’
#
# 100%[======================================>] 3,415       --.-K/s   in 0s
#
# 2020-05-12 23:32:37 (20.7 MB/s) - ‘Stations_wiki.csv’ saved [3415/3415]

# %%
file = 'Stations_wiki.csv'
df_stations = pd.read_csv(file, index_col=0)
df_stations.head(5)
# Out:
#                         Station            Opened         Type
# 0                  Alessandrino   9 novembre 2014  sotterranea
# 1                      Anagnina    11 giugno 1980  sotterranea
# 2            Arco di Travertino  16 febbraio 1980  sotterranea
# 3            Baldo degli Ubaldi   1º gennaio 2000  sotterranea
# 4  Barberini - Fontana di Trevi  16 febbraio 1980  sotterranea

# %%
#remove day and month from Open Date
df_stations.replace({'Opened': r'^[0-9]+\º*\s[a-z]+\s'}, {'Opened': ''}, regex=True, inplace=True)

#clean some dates
df_stations.replace({'Opened': r'\[1\]'}, {'Opened': ''}, regex=True, inplace=True)
df_stations.replace({'Opened': '1980 (MA)12 maggio 2018 (MC)'}, '1980', inplace=True)
df_stations.replace({'Opened': '1955 (MB)16 febbraio 1980 (MA)'}, '1955', inplace=True)
df_stations.replace({'Station': r'Manzoni\s.*'}, {'Station': 'Manzoni'}, regex=True, inplace=True)
df_stations.replace({'Station': r'Furio\sCamillo.*'}, {'Station': 'Furio Camillo'}, regex=True, inplace=True)
df_stations.replace({'Station': r'Colli\sAlbani.*'}, {'Station': 'Colli Albani'}, regex=True, inplace=True)
df_stations.replace({'Station': r'Porta\sFurba.*'}, {'Station': 'Porta Furba - Quadraro'}, regex=True, inplace=True)
df_stations.replace({'Station': r'Sant\'Agnese\/Annibaliano'}, {'Station': 'Sant Agnese - Annibaliano'}, regex=True, inplace=True)

#translate types of stations
df_stations.replace({'Type': 'sotterranea'}, 'underground', inplace=True)
df_stations.replace({'Type': 'in superficie'}, 'surface', inplace=True)
df_stations.replace({'Type': 'in galleria artificiale'}, 'in artificial gallery', inplace=True)
df_stations.replace({'Type': 'sopraelevata'}, 'overground', inplace=True)

df_stations.head(5)
# Out:
#                         Station Opened         Type
# 0                  Alessandrino   2014  underground
# 1                      Anagnina   1980  underground
# 2            Arco di Travertino   1980  underground
# 3            Baldo degli Ubaldi   2000  underground
# 4  Barberini - Fontana di Trevi   1980  underground

# %%
df_stations.shape
# Out:
# (73, 3)

# %%
#csv = df_stations.to_csv(index=False)
#print(csv)

# %%
#get geo data for Rome subway stations
# !wget -O 'Rome_Metro.csv' https://raw.githubusercontent.com/riccione/Coursera_Capstone/master/Rome_Metro.csv
# Out:
# --2020-05-12 23:32:47--  https://raw.githubusercontent.com/riccione/Coursera_Capstone/master/Rome_Metro.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 199.232.8.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|199.232.8.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3072 (3.0K) [text/plain]
# Saving to: ‘Rome_Metro.csv’
#
# 100%[======================================>] 3,072       --.-K/s   in 0s
#
# 2020-05-12 23:32:47 (21.0 MB/s) - ‘Rome_Metro.csv’ saved [3072/3072]

# %%
file = 'Rome_Metro.csv'
df_geo = pd.read_csv(file,sep=",")
df_geo.columns = ['Station', 'Opened', 'Line', 'Latitude', 'Longitude']
#drop columns Opened
df_geo.drop(columns=['Opened'], inplace=True)
df_geo.head(5)
# Out:
#               Station Line   Latitude  Longitude
# 0          Battistini    A  41.906461  12.414722
# 1            Cornelia    A  41.902222  12.425278
# 2  Baldo degli Ubaldi    A  41.898889  12.432778
# 3       Valle Aurelia    A  41.903056  12.441667
# 4               Cipro    A  41.907500  12.447500

# %%
#sort dataframe
df_geo.sort_values(by=['Station'], inplace=True)
df_geo.reset_index(drop=True, inplace=True)
df_geo.head(5)
# Out:
#                         Station Line   Latitude  Longitude
# 0                  Alessandrino    C  41.871349  12.578701
# 1                      Anagnina    A  41.842778  12.586111
# 2            Arco di Travertino    A  41.866705  12.535070
# 3            Baldo degli Ubaldi    A  41.898889  12.432778
# 4  Barberini - Fontana di Trevi    A  41.903889  12.488889

# %%
index = 0
for t in df_geo.duplicated('Station'):
        if (t):
            print(index, t)
        index += 1
# Out:
# 59 True
# 66 True

# %%
#rename Basilica S. Paolo to Basilica San Paolo
df_geo.replace({'Station': 'Basilica S. Paolo'}, 'Basilica San Paolo', inplace=True)
#rename Manzoni – Museo della Liberazione to Manzoni
df_geo.replace({'Station': r'Manzoni\s.*'}, {'Station': 'Manzoni'}, regex=True, inplace=True)
df_geo.replace({'Station': r'Ponte\sLungo.*'}, {'Station': 'Ponte Lungo'}, regex=True, inplace=True)
df_geo.replace({'Station': r'Furio\sCamillo.*'}, {'Station': 'Furio Camillo'}, regex=True, inplace=True)
df_geo.replace({'Station': r'Colli\sAlbani.*'}, {'Station': 'Colli Albani'}, regex=True, inplace=True)
df_geo.replace({'Station': r'Numidio\sQuadrato.*'}, {'Station': 'Numidio Quadrato'}, regex=True, inplace=True)
df_geo.replace({'Station': r'Lucio\sSestio.*'}, {'Station': 'Lucio Sestio'}, regex=True, inplace=True)
df_geo.replace({'Station': r'Sant\'Agnese\s.\sAnnibaliano'}, {'Station': 'Sant Agnese - Annibaliano'}, regex=True, inplace=True)
df_geo[50:70]
#df_stations[20:30]
# Out:
#                            Station Line   Latitude  Longitude
# 50                     Policlinico    B  41.908889  12.511667
# 51                     Ponte Lungo    A  41.877845  12.518957
# 52                   Ponte Mammolo    B  41.920556  12.565000
# 53          Porta Furba - Quadraro    A  41.863790  12.548206
# 54                     Quintiliani    B  41.915556  12.538611
# 55                      Re di Roma    A  41.881635  12.514405
# 56                        Rebibbia    B  41.925833  12.573056
# 57  Repubblica - Teatro dell'Opera    A  41.902500  12.495556
# 58                    San Giovanni    C  41.885278  12.509444
# 59                    San Giovanni    A  41.885278  12.509444
# 60       Sant Agnese - Annibaliano    B  41.923889  12.515833
# 61        Santa Maria del Soccorso    B  41.915556  12.560833
# 62                          Spagna    A  41.906500  12.483056
# 63                      Subaugusta    A  41.853831  12.567701
# 64                           Teano    C  41.889230  12.551311
# 65                         Termini    A  41.901542  12.500596
# 66                         Termini    B  41.901542  12.500596
# 67                       Tiburtina    B  41.910833  12.529444
# 68                    Torre Angela    C  41.864318  12.625711
# 69                      Torre Gaia    C  41.864085  12.635554

# %%
#remove San Giovanni and Termini, basically they are not duplicates
#these stations duplicates, because they exist on the crossing of two lines: San Giovanni A and C; Termini A and B. 
#The exits to different lines were build in different periods of time, however it is not important for our study.
df_geo[df_geo['Station'] == "San Giovanni"]
# Out:
#          Station Line   Latitude  Longitude
# 58  San Giovanni    C  41.885278  12.509444
# 59  San Giovanni    A  41.885278  12.509444

# %%
df_geo.iat[58,1] = 'AC'
counter = len(df_geo[df_geo['Station'] == "San Giovanni"])
if (counter > 1):
    df_geo.drop(df_geo.index[59], inplace=True)
df_geo[df_geo['Station'] == "San Giovanni"]
# Out:
#          Station Line   Latitude  Longitude
# 58  San Giovanni   AC  41.885278  12.509444

# %%
df_geo.reset_index(drop=True, inplace=True)
df_geo[df_geo['Station'] == 'Termini']
# Out:
#     Station Line   Latitude  Longitude
# 64  Termini    A  41.901542  12.500596
# 65  Termini    B  41.901542  12.500596

# %%
df_geo.iat[64,1] = 'AB'
counter = len(df_geo[df_geo['Station'] == "Termini"])
print(counter)
if (counter > 1):
    df_geo.drop(df_geo.index[65], inplace=True)
df_geo[df_geo['Station'] == "Termini"]
# Out:
# 2
#     Station Line   Latitude  Longitude
# 64  Termini   AB  41.901542  12.500596

# %%
df_geo.shape
# Out:
# (73, 4)

# %%
df_geo['Station'].value_counts()
# Out:
# Subaugusta                                 1
# Repubblica - Teatro dell'Opera             1
# Sant Agnese - Annibaliano                  1
# Numidio Quadrato                           1
# Parco di Centocelle                        1
# Piramide                                   1
# Flaminio - Piazza del Popolo               1
# Santa Maria del Soccorso                   1
# San Giovanni                               1
# Giardinetti                                1
# Monti Tiburtini                            1
# Giulio Agricola                            1
# Policlinico                                1
# Torrenova                                  1
# Due Leoni-Fontana Candida                  1
# Castro Pretorio                            1
# Colosseo                                   1
# Gardenie                                   1
# Graniti                                    1
# Jonio                                      1
# Manzoni                                    1
# Furio Camillo                              1
# Valle Aurelia                              1
# Barberini - Fontana di Trevi               1
# Mirti                                      1
# Cavour                                     1
# Conca d'Oro                                1
# Arco di Travertino                         1
# Spagna                                     1
# Alessandrino                               1
#                                           ..
# Pietralata                                 1
# Tiburtina                                  1
# Libia                                      1
# Torre Maura                                1
# Ponte Mammolo                              1
# Ponte Lungo                                1
# Bologna                                    1
# Torre Gaia                                 1
# Monte Compatri-Pantano                     1
# Cipro                                      1
# EUR Magliana                               1
# Grotte Celoni                              1
# Ottaviano - San Pietro - Musei Vaticani    1
# Malatesta                                  1
# Torre Angela                               1
# Garbatella                                 1
# Finocchio                                  1
# Re di Roma                                 1
# Cinecittà                                  1
# Torre Spaccata                             1
# Rebibbia                                   1
# Anagnina                                   1
# Porta Furba - Quadraro                     1
# Laurentina                                 1
# EUR Palasport                              1
# Bolognetta                                 1
# Teano                                      1
# Marconi                                    1
# Battistini                                 1
# Quintiliani                                1
# Name: Station, Length: 73, dtype: int64

# %%
df = df_stations.merge(df_geo, on="Station", how = 'inner')
df[20:30]
# Out:
#                          Station Opened                   Type Line  \
# 20                     EUR Fermi   1955  in artificial gallery    B
# 21                  EUR Magliana   1955                surface    B
# 22                 EUR Palasport   1955  in artificial gallery    B
# 23                     Finocchio   2014            underground    C
# 24  Flaminio - Piazza del Popolo   1980            underground    A
# 25                 Furio Camillo   1980            underground    A
# 26                    Garbatella   1990                surface    B
# 27                      Gardenie   2015            underground    C
# 28                   Giardinetti   2014             in trincea    C
# 29               Giulio Agricola   1980            underground    A
#
#      Latitude  Longitude
# 20  41.828611  12.471111
# 21  41.839444  12.463333
# 22  41.830000  12.466667
# 23  41.865482  12.687809
# 24  41.911944  12.475833
# 25  41.874722  12.523056
# 26  41.866667  12.483333
# 27  41.886300  12.561700
# 28  41.864275  12.610113
# 29  41.856598  12.562633

# %%
df.shape
# Out:
# (73, 6)

# %%
line_a = df[df['Line']=='A']
line_ab = df[df['Line']=='AB']
line_ac = df[df['Line']=='AC']
line_a = line_a.append(line_ab)
line_a = line_a.append(line_ac)
line_a
# Out:
#                                     Station Opened         Type Line  \
# 1                                  Anagnina   1980  underground    A
# 2                        Arco di Travertino   1980  underground    A
# 3                        Baldo degli Ubaldi   2000  underground    A
# 4              Barberini - Fontana di Trevi   1980  underground    A
# 6                                Battistini   2000  underground    A
# 12                                Cinecittà   1980  underground    A
# 13                                    Cipro   1999  underground    A
# 15                             Colli Albani   1980  underground    A
# 18                                 Cornelia   2000  underground    A
# 24             Flaminio - Piazza del Popolo   1980  underground    A
# 25                            Furio Camillo   1980  underground    A
# 29                          Giulio Agricola   1980  underground    A
# 34                                  Lepanto   1980  underground    A
# 37                             Lucio Sestio   1980  underground    A
# 39                                  Manzoni   1980  underground    A
# 44                         Numidio Quadrato   1980  underground    A
# 45  Ottaviano - San Pietro - Musei Vaticani   1980  underground    A
# 51                              Ponte Lungo   1980  underground    A
# 53                   Porta Furba - Quadraro   1980  underground    A
# 55                               Re di Roma   1980  underground    A
# 57           Repubblica - Teatro dell'Opera   1980  underground    A
# 61                                   Spagna   1980  underground    A
# 62                               Subaugusta   1980  underground    A
# 71                            Valle Aurelia   1999  underground    A
# 72                        Vittorio Emanuele   1980  underground    A
# 64                                  Termini   1955  underground   AB
# 58                             San Giovanni   1980  underground   AC
#
#      Latitude  Longitude
# 1   41.842778  12.586111
# 2   41.866705  12.535070
# 3   41.898889  12.432778
# 4   41.903889  12.488889
# 6   41.906461  12.414722
# 12  41.849300  12.574377
# 13  41.907500  12.447500
# 15  41.869400  12.530100
# 18  41.902222  12.425278
# 24  41.911944  12.475833
# 25  41.874722  12.523056
# 29  41.856598  12.562633
# 34  41.911389  12.466111
# 37  41.859697  12.557283
# 39  41.890278  12.506944
# 44  41.862133  12.552658
# 45  41.909444  12.458056
# 51  41.877845  12.518957
# 53  41.863790  12.548206
# 55  41.881635  12.514405
# 57  41.902500  12.495556
# 61  41.906500  12.483056
# 62  41.853831  12.567701
# 71  41.903056  12.441667
# 72  41.894444  12.504167
# 64  41.901542  12.500596
# 58  41.885278  12.509444

# %%
#reorder line_a stations in a right order
line_a = line_a.reindex([6,18,3,71,13,45,34,24,61,4,57,64,72,39,58,55,51,25,15,2,53,44,37,29,62,12,1])
line_a
# Out:
#                                     Station Opened         Type Line  \
# 6                                Battistini   2000  underground    A
# 18                                 Cornelia   2000  underground    A
# 3                        Baldo degli Ubaldi   2000  underground    A
# 71                            Valle Aurelia   1999  underground    A
# 13                                    Cipro   1999  underground    A
# 45  Ottaviano - San Pietro - Musei Vaticani   1980  underground    A
# 34                                  Lepanto   1980  underground    A
# 24             Flaminio - Piazza del Popolo   1980  underground    A
# 61                                   Spagna   1980  underground    A
# 4              Barberini - Fontana di Trevi   1980  underground    A
# 57           Repubblica - Teatro dell'Opera   1980  underground    A
# 64                                  Termini   1955  underground   AB
# 72                        Vittorio Emanuele   1980  underground    A
# 39                                  Manzoni   1980  underground    A
# 58                             San Giovanni   1980  underground   AC
# 55                               Re di Roma   1980  underground    A
# 51                              Ponte Lungo   1980  underground    A
# 25                            Furio Camillo   1980  underground    A
# 15                             Colli Albani   1980  underground    A
# 2                        Arco di Travertino   1980  underground    A
# 53                   Porta Furba - Quadraro   1980  underground    A
# 44                         Numidio Quadrato   1980  underground    A
# 37                             Lucio Sestio   1980  underground    A
# 29                          Giulio Agricola   1980  underground    A
# 62                               Subaugusta   1980  underground    A
# 12                                Cinecittà   1980  underground    A
# 1                                  Anagnina   1980  underground    A
#
#      Latitude  Longitude
# 6   41.906461  12.414722
# 18  41.902222  12.425278
# 3   41.898889  12.432778
# 71  41.903056  12.441667
# 13  41.907500  12.447500
# 45  41.909444  12.458056
# 34  41.911389  12.466111
# 24  41.911944  12.475833
# 61  41.906500  12.483056
# 4   41.903889  12.488889
# 57  41.902500  12.495556
# 64  41.901542  12.500596
# 72  41.894444  12.504167
# 39  41.890278  12.506944
# 58  41.885278  12.509444
# 55  41.881635  12.514405
# 51  41.877845  12.518957
# 25  41.874722  12.523056
# 15  41.869400  12.530100
# 2   41.866705  12.535070
# 53  41.863790  12.548206
# 44  41.862133  12.552658
# 37  41.859697  12.557283
# 29  41.856598  12.562633
# 62  41.853831  12.567701
# 12  41.849300  12.574377
# 1   41.842778  12.586111

# %%
line_b = df[df['Line']=='B']
line_b = line_b.append(line_ab)
line_b_left = line_b[line_b['Station'] != 'Rebibbia']
line_b_left = line_b[line_b['Station'] != 'Ponte Mammolo']
line_b_left = line_b[line_b['Station'] != 'Pietralata']
line_b_left = line_b[line_b['Station'] != 'Monti Tiburtini']
line_b_left = line_b[line_b['Station'] != 'Quintiliani']
line_b_left = line_b[line_b['Station'] != 'Tiburtina']
line_b_left
# Out:
#                       Station Opened                   Type Line   Latitude  \
# 5          Basilica San Paolo   1955             overground    B  41.856111
# 7                     Bologna   1990            underground    B  41.913333
# 10            Castro Pretorio   1990            underground    B  41.906111
# 11                     Cavour   1955            underground    B  41.895000
# 14              Circo Massimo   1955            underground    B  41.883611
# 16                   Colosseo   1955            underground    B  41.891389
# 17                Conca d'Oro   2012            underground    B  41.939444
# 20                  EUR Fermi   1955  in artificial gallery    B  41.828611
# 21               EUR Magliana   1955                surface    B  41.839444
# 22              EUR Palasport   1955  in artificial gallery    B  41.830000
# 26                 Garbatella   1990                surface    B  41.866667
# 32                      Jonio   2015            underground    B  41.946389
# 33                 Laurentina   1955  in artificial gallery    B  41.826944
# 35                      Libia   2012            underground    B  41.932778
# 40                    Marconi   1994                surface    B  41.849444
# 43            Monti Tiburtini   1990            underground    B  41.915833
# 47                 Pietralata   1990            underground    B  41.914722
# 49                   Piramide   1955             in trincea    B  41.875556
# 50                Policlinico   1990            underground    B  41.908889
# 52              Ponte Mammolo   1995             overground    B  41.920556
# 54                Quintiliani   2003            underground    B  41.915556
# 56                   Rebibbia   1990            underground    B  41.925833
# 59   Santa Maria del Soccorso   1990            underground    B  41.915556
# 60  Sant Agnese - Annibaliano   2012            underground    B  41.923889
# 64                    Termini   1955            underground   AB  41.901542
#
#     Longitude
# 5   12.478194
# 7   12.520556
# 10  12.505556
# 11  12.493611
# 14  12.488056
# 16  12.491389
# 17  12.527778
# 20  12.471111
# 21  12.463333
# 22  12.466667
# 26  12.483333
# 32  12.528056
# 33  12.481111
# 35  12.520556
# 40  12.475556
# 43  12.547778
# 47  12.555000
# 49  12.482222
# 50  12.511667
# 52  12.565000
# 54  12.538611
# 56  12.573056
# 59  12.560833
# 60  12.515833
# 64  12.500596

# %%
#reorder line_a stations in a right order
line_b_left = line_b_left.reindex([32,17,35,60,7,50,10,64,11,16,14,49,26,5,40,21,22,20,33])
line_b_left
# Out:
#                       Station Opened                   Type Line   Latitude  \
# 32                      Jonio   2015            underground    B  41.946389
# 17                Conca d'Oro   2012            underground    B  41.939444
# 35                      Libia   2012            underground    B  41.932778
# 60  Sant Agnese - Annibaliano   2012            underground    B  41.923889
# 7                     Bologna   1990            underground    B  41.913333
# 50                Policlinico   1990            underground    B  41.908889
# 10            Castro Pretorio   1990            underground    B  41.906111
# 64                    Termini   1955            underground   AB  41.901542
# 11                     Cavour   1955            underground    B  41.895000
# 16                   Colosseo   1955            underground    B  41.891389
# 14              Circo Massimo   1955            underground    B  41.883611
# 49                   Piramide   1955             in trincea    B  41.875556
# 26                 Garbatella   1990                surface    B  41.866667
# 5          Basilica San Paolo   1955             overground    B  41.856111
# 40                    Marconi   1994                surface    B  41.849444
# 21               EUR Magliana   1955                surface    B  41.839444
# 22              EUR Palasport   1955  in artificial gallery    B  41.830000
# 20                  EUR Fermi   1955  in artificial gallery    B  41.828611
# 33                 Laurentina   1955  in artificial gallery    B  41.826944
#
#     Longitude
# 32  12.528056
# 17  12.527778
# 35  12.520556
# 60  12.515833
# 7   12.520556
# 50  12.511667
# 10  12.505556
# 64  12.500596
# 11  12.493611
# 16  12.491389
# 14  12.488056
# 49  12.482222
# 26  12.483333
# 5   12.478194
# 40  12.475556
# 21  12.463333
# 22  12.466667
# 20  12.471111
# 33  12.481111

# %%
def remove_stations_from_line(dataset, station_list):
    for station in station_list:
        dataset = dataset[dataset['Station'] != station]
    return dataset

# %%
line_b_right = remove_stations_from_line(line_b,['Jonio','Conca d\'Oro','Libia','Sant Agnese - Annibaliano','Policlinico','Castro Pretorio',
                                                 'Termini','Cavour','Colosseo','Circo Massimo','Piramide','Garbatella','Basilica San Paolo',
                                                 'Marconi','EUR Magliana','EUR Palasport','EUR Fermi','Laurentina'])
line_b_right
# Out:
#                      Station Opened         Type Line   Latitude  Longitude
# 7                    Bologna   1990  underground    B  41.913333  12.520556
# 43           Monti Tiburtini   1990  underground    B  41.915833  12.547778
# 47                Pietralata   1990  underground    B  41.914722  12.555000
# 52             Ponte Mammolo   1995   overground    B  41.920556  12.565000
# 54               Quintiliani   2003  underground    B  41.915556  12.538611
# 56                  Rebibbia   1990  underground    B  41.925833  12.573056
# 59  Santa Maria del Soccorso   1990  underground    B  41.915556  12.560833
# 65                 Tiburtina   1990  underground    B  41.910833  12.529444

# %%
#reorder line_a stations in a right order
line_b_right = line_b_right.reindex([56,52,59,47,43,54,65,7])
line_b_right
# Out:
#                      Station Opened         Type Line   Latitude  Longitude
# 56                  Rebibbia   1990  underground    B  41.925833  12.573056
# 52             Ponte Mammolo   1995   overground    B  41.920556  12.565000
# 59  Santa Maria del Soccorso   1990  underground    B  41.915556  12.560833
# 47                Pietralata   1990  underground    B  41.914722  12.555000
# 43           Monti Tiburtini   1990  underground    B  41.915833  12.547778
# 54               Quintiliani   2003  underground    B  41.915556  12.538611
# 65                 Tiburtina   1990  underground    B  41.910833  12.529444
# 7                    Bologna   1990  underground    B  41.913333  12.520556

# %%
line_c = df[df['Line']=='C']
line_c = line_c.append(line_ac)
line_c
# Out:
#                       Station Opened         Type Line   Latitude  Longitude
# 0                Alessandrino   2014  underground    C  41.871349  12.578701
# 8                  Bolognetta   2014   overground    C  41.865134  12.680883
# 9                 Borghesiana   2014   in trincea    C  41.864707  12.667300
# 19  Due Leoni-Fontana Candida   2014      surface    C  41.864907  12.658093
# 23                  Finocchio   2014  underground    C  41.865482  12.687809
# 27                   Gardenie   2015  underground    C  41.886300  12.561700
# 28                Giardinetti   2014   in trincea    C  41.864275  12.610113
# 30                    Graniti   2014      surface    C  41.865690  12.698020
# 31              Grotte Celoni   2014      surface    C  41.862666  12.646096
# 36                       Lodi   2015  underground    C  41.886732  12.517762
# 38                  Malatesta   2015  underground    C  41.887300  12.540200
# 41                      Mirti   2015  underground    C  41.881100  12.566600
# 42     Monte Compatri-Pantano   2014   overground    C  41.865688  12.707623
# 46        Parco di Centocelle   2014  underground    C  41.874619  12.568030
# 48                    Pigneto   2015  underground    C  41.888456  12.528178
# 63                      Teano   2015  underground    C  41.889230  12.551311
# 66               Torre Angela   2014      surface    C  41.864318  12.625711
# 67                 Torre Gaia   2014      surface    C  41.864085  12.635554
# 68                Torre Maura   2014  underground    C  41.866916  12.596878
# 69             Torre Spaccata   2014  underground    C  41.869000  12.586600
# 70                  Torrenova   2014      surface    C  41.863320  12.616840
# 58               San Giovanni   1980  underground   AC  41.885278  12.509444

# %%
#reorder line_a stations in a right order
line_c = line_c.reindex([58,36,48,38,63,27,41,46,0,69,68,28,70,66,67,31,19,9,8,23,30,42])
line_c
# Out:
#                       Station Opened         Type Line   Latitude  Longitude
# 58               San Giovanni   1980  underground   AC  41.885278  12.509444
# 36                       Lodi   2015  underground    C  41.886732  12.517762
# 48                    Pigneto   2015  underground    C  41.888456  12.528178
# 38                  Malatesta   2015  underground    C  41.887300  12.540200
# 63                      Teano   2015  underground    C  41.889230  12.551311
# 27                   Gardenie   2015  underground    C  41.886300  12.561700
# 41                      Mirti   2015  underground    C  41.881100  12.566600
# 46        Parco di Centocelle   2014  underground    C  41.874619  12.568030
# 0                Alessandrino   2014  underground    C  41.871349  12.578701
# 69             Torre Spaccata   2014  underground    C  41.869000  12.586600
# 68                Torre Maura   2014  underground    C  41.866916  12.596878
# 28                Giardinetti   2014   in trincea    C  41.864275  12.610113
# 70                  Torrenova   2014      surface    C  41.863320  12.616840
# 66               Torre Angela   2014      surface    C  41.864318  12.625711
# 67                 Torre Gaia   2014      surface    C  41.864085  12.635554
# 31              Grotte Celoni   2014      surface    C  41.862666  12.646096
# 19  Due Leoni-Fontana Candida   2014      surface    C  41.864907  12.658093
# 9                 Borghesiana   2014   in trincea    C  41.864707  12.667300
# 8                  Bolognetta   2014   overground    C  41.865134  12.680883
# 23                  Finocchio   2014  underground    C  41.865482  12.687809
# 30                    Graniti   2014      surface    C  41.865690  12.698020
# 42     Monte Compatri-Pantano   2014   overground    C  41.865688  12.707623

# %%
#lets get the point of city center: Barberini - Fontana di Trevi
latitude = df.loc[4,'Latitude']
longitude = df.loc[4, 'Longitude']

print(latitude)
print(longitude)
type(latitude)
type(longitude)
# Out:
# 41.903889
# 12.488889
# numpy.float64

# %% [markdown]
# ![Fontana di Trevi](https://upload.wikimedia.org/wikipedia/commons/thumb/e/e1/Panorama_of_Trevi_fountain_2015.jpg/640px-Panorama_of_Trevi_fountain_2015.jpg)

# %%
rome_lat_long = [latitude, longitude]

# create map of Toronto using latitude and longitude values
rome_map = folium.Map(location=rome_lat_long, zoom_start=12)

#colors for markers
color_A = '#FFA500' #official color is orange
color_B = '#0000FF' #official color is blue
color_C = '#008000' #official color is green
color_other = '#FF0000'

#create empty list
lines=[]

#add markers to map
for lat, lng, label, line in zip(df['Latitude'],df['Longitude'],df['Station'],df['Line']):
    label = folium.Popup(label, parse_html=True)
    if(line=='A'):
        color_marker=color_A
    elif(line=='B'):
        color_marker=color_B
    elif(line=='C'):
        color_marker=color_C
    else:
        color_marker=color_other
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=color_marker,
        fill=True,
        fill_color=color_marker,
        fill_opacity=0.75,
        parse_html=False).add_to(rome_map)
    
#draw lines function
def draw_lines(dataset):
    lines=[]
    for lat, lng in zip(dataset['Latitude'],dataset['Longitude']):
        lines.append(tuple([lat, lng]))
    return lines
        
#add lines A
folium.PolyLine(draw_lines(line_a), color=color_A, weight=2.5, opacity=1).add_to(rome_map)   
#add lines B left
folium.PolyLine(draw_lines(line_b_left), color=color_B, weight=2.5, opacity=1).add_to(rome_map)   
#add lines B right
folium.PolyLine(draw_lines(line_b_right), color=color_B, weight=2.5, opacity=1).add_to(rome_map)
#add lines C right
folium.PolyLine(draw_lines(line_c), color=color_C, weight=2.5, opacity=1).add_to(rome_map)

rome_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
rome_map.save('Rome_map.html')

# %%
#save dataset to csv file
df.to_csv('Stations.csv')

# %% [markdown]
# ## Foursquare API

# %%
LIMIT = 100
radius = 1000

# %%
# @hidden_cell
CLIENT_ID = ''
CLIENT_SECRET = ''
VERSION = '20200425'

# %% [markdown]
# ### Analysis of venues categories

# %%
categories_url = 'https://api.foursquare.com/v2/venues/categories?client_id={}&client_secret={}&v={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
            
# make the GET request
results = requests.get(categories_url).json()

# %%
len(results['response']['categories'])
# Out:
# 10

# %%
categories_list = []
# Let's print only the top-level categories and their IDs and also add them to categories_list

def print_categories(categories, level=0, max_level=0):    
    if level>max_level: return
    out = ''
    out += '-'*level
    for category in categories:
        print(out + category['name'] + ' (' + category['id'] + ')')
        print_categories(category['categories'], level+1, max_level)
        categories_list.append((category['name'], category['id']))

print_categories(results['response']['categories'], 0, 0)
# Out:
# Arts & Entertainment (4d4b7104d754a06370d81259)
# College & University (4d4b7105d754a06372d81259)
# Event (4d4b7105d754a06373d81259)
# Food (4d4b7105d754a06374d81259)
# Nightlife Spot (4d4b7105d754a06376d81259)
# Outdoors & Recreation (4d4b7105d754a06377d81259)
# Professional & Other Places (4d4b7105d754a06375d81259)
# Residence (4e67e38e036454776db1fb3a)
# Shop & Service (4d4b7105d754a06378d81259)
# Travel & Transport (4d4b7105d754a06379d81259)

# %% [markdown]
# ### Query number of venues in each category

# %%
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
def get_venues_count(latitude, longitude, radius, categoryId):
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&categoryId={}'.format(
                CLIENT_ID, 
                CLIENT_SECRET, 
                VERSION,
                latitude, 
                longitude,
                radius,
                categoryId)

    # make the GET request
    results = requests.get(url).json()
    return results['response']['totalResults']

# %%
#Create new dataframe to store venues data
stations_venues_df = df.copy()
for c in categories_list:
    stations_venues_df[c[0]] = 0
stations_venues_df.head()
# Out:
#                         Station Opened         Type Line   Latitude  \
# 0                  Alessandrino   2014  underground    C  41.871349
# 1                      Anagnina   1980  underground    A  41.842778
# 2            Arco di Travertino   1980  underground    A  41.866705
# 3            Baldo degli Ubaldi   2000  underground    A  41.898889
# 4  Barberini - Fontana di Trevi   1980  underground    A  41.903889
#
#    Longitude  Arts & Entertainment  College & University  Event  Food  \
# 0  12.578701                     0                     0      0     0
# 1  12.586111                     0                     0      0     0
# 2  12.535070                     0                     0      0     0
# 3  12.432778                     0                     0      0     0
# 4  12.488889                     0                     0      0     0
#
#    Nightlife Spot  Outdoors & Recreation  Professional & Other Places  \
# 0               0                      0                            0
# 1               0                      0                            0
# 2               0                      0                            0
# 3               0                      0                            0
# 4               0                      0                            0
#
#    Residence  Shop & Service  Travel & Transport
# 0          0               0                   0
# 1          0               0                   0
# 2          0               0                   0
# 3          0               0                   0
# 4          0               0                   0

# %%
#SKIP - use too many request for sandbox
#Request number of venues
#for station, lat, lng in zip(df['Station'],df['Latitude'],df['Longitude']):
for i, row in stations_venues_df.iterrows():
    print(i)
    for c in categories_list:
        stations_venues_df.loc[i, c[0]] = get_venues_count(row.Latitude,row.Longitude, radius=1000, categoryId=c[1])
    stations_venues_df.to_csv('Stations_venues.csv')

# %%
#get saved data for Rome subway stations venues by categories
# !wget -O 'Stations_venues.csv' https://raw.githubusercontent.com/riccione/Coursera_Capstone/master/Stations_venues.csv
# Out:
# --2020-05-12 23:34:30--  https://raw.githubusercontent.com/riccione/Coursera_Capstone/master/Stations_venues.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 199.232.8.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|199.232.8.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6202 (6.1K) [text/plain]
# Saving to: ‘Stations_venues.csv’
#
# 100%[======================================>] 6,202       --.-K/s   in 0s
#
# 2020-05-12 23:34:30 (33.1 MB/s) - ‘Stations_venues.csv’ saved [6202/6202]

# %%
stations_venues_df = pd.read_csv('Stations_venues.csv', index_col=0)
stations_venues_df.head()
# Out:
#                         Station  Opened         Type Line   Latitude  \
# 0                  Alessandrino    2014  underground    C  41.871349
# 1                      Anagnina    1980  underground    A  41.842778
# 2            Arco di Travertino    1980  underground    A  41.866705
# 3            Baldo degli Ubaldi    2000  underground    A  41.898889
# 4  Barberini - Fontana di Trevi    1980  underground    A  41.903889
#
#    Longitude  Arts & Entertainment  College & University  Event  Food  \
# 0  12.578701                     4                     7      1     7
# 1  12.586111                     3                     3      0     9
# 2  12.535070                     5                     5      0    37
# 3  12.432778                    13                     8      1    49
# 4  12.488889                    49                    27      9   230
#
#    Nightlife Spot  Outdoors & Recreation  Professional & Other Places  \
# 0               5                      8                            6
# 1               4                      1                            3
# 2              16                     17                           16
# 3               5                     19                           28
# 4              88                     74                           63
#
#    Residence  Shop & Service  Travel & Transport
# 0          3              13                   5
# 1          0              12                  10
# 2          6              23                   8
# 3          4              48                  30
# 4          5              56                  92

# %% [markdown]
# ### Visualize data

# %%
stations_venues_df[['Arts & Entertainment','College & University','Event','Food','Nightlife Spot','Outdoors & Recreation','Professional & Other Places','Residence','Shop & Service','Travel & Transport']].describe()
# Out:
#        Arts & Entertainment  College & University      Event        Food  \
# count             73.000000             73.000000  73.000000   73.000000
# mean              10.438356             10.260274   1.986301   60.767123
# std               12.225868             12.225914   3.255308   58.152224
# min                0.000000              0.000000   0.000000    4.000000
# 25%                3.000000              3.000000   0.000000   15.000000
# 50%                5.000000              6.000000   0.000000   44.000000
# 75%               13.000000             12.000000   3.000000   90.000000
# max               49.000000             67.000000  13.000000  232.000000
#
#        Nightlife Spot  Outdoors & Recreation  Professional & Other Places  \
# count       73.000000              73.000000                    73.000000
# mean        18.643836              19.794521                    21.945205
# std         19.896517              17.933487                    15.730270
# min          0.000000               1.000000                     2.000000
# 25%          5.000000               7.000000                     9.000000
# 50%         10.000000              14.000000                    18.000000
# 75%         25.000000              24.000000                    32.000000
# max         88.000000              89.000000                    63.000000
#
#        Residence  Shop & Service  Travel & Transport
# count  73.000000       73.000000           73.000000
# mean    4.904110       26.273973           24.191781
# std     4.308146       13.507467           26.187177
# min     0.000000        3.000000            3.000000
# 25%     2.000000       16.000000            6.000000
# 50%     4.000000       26.000000           10.000000
# 75%     6.000000       36.000000           39.000000
# max    19.000000       56.000000           98.000000

# %%
tmp_df = stations_venues_df[['Arts & Entertainment','College & University','Event','Food','Nightlife Spot','Outdoors & Recreation','Professional & Other Places','Residence','Shop & Service','Travel & Transport']]
tmp_df.head(3)
# Out:
#    Arts & Entertainment  College & University  Event  Food  Nightlife Spot  \
# 0                     4                     7      1     7               5
# 1                     3                     3      0     9               4
# 2                     5                     5      0    37              16
#
#    Outdoors & Recreation  Professional & Other Places  Residence  \
# 0                      8                            6          3
# 1                      1                            3          0
# 2                     17                           16          6
#
#    Shop & Service  Travel & Transport
# 0              13                   5
# 1              12                  10
# 2              23                   8

# %%
import seaborn as sns
plt.figure(figsize=(20, 10))
plt.xticks(rotation='vertical')
sns.boxplot

ax = sns.boxplot(data = tmp_df)
#ax = sns.swarmplot(data=tmp_df, color="black", edgecolor="gray")
ax.set_ylabel('Count of venues', fontsize=20)
ax.set_xlabel('Venue category', fontsize=20)
ax.tick_params(labelsize=20)
plt.xticks(rotation=45, ha='right')

plt.show()

# %% [markdown]
# As expected for Italy, the most frequent category is food. In Italy food is very important part of life.
# Event and Residence are not important categories, their number is not high and we can easily remove it from our dataframe.
# Reference: https://developer.foursquare.com/docs/build-with-foursquare/categories/

# %%
if 'Event' in tmp_df.columns:
    tmp_df.drop(columns=['Event', 'Residence'], inplace=True)
    stations_venues_df.drop(columns=['Event', 'Residence'], inplace=True)
    categories_list = list(filter(lambda x: x[0] != 'Event', categories_list))
    categories_list = list(filter(lambda x: x[0] != 'Residence', categories_list))
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
#normalize data
from sklearn.preprocessing import MinMaxScaler

X = tmp_df.values
cluster_dataset = MinMaxScaler().fit_transform(X)
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
cluster_df = pd.DataFrame(cluster_dataset)
cluster_df.columns = [c[0] for c in categories_list]
cluster_df.head()
# Out:
#    Arts & Entertainment  College & University      Food  Nightlife Spot  \
# 0              0.081633              0.104478  0.013158        0.056818
# 1              0.061224              0.044776  0.021930        0.045455
# 2              0.102041              0.074627  0.144737        0.181818
# 3              0.265306              0.119403  0.197368        0.056818
# 4              1.000000              0.402985  0.991228        1.000000
#
#    Outdoors & Recreation  Professional & Other Places  Shop & Service  \
# 0               0.079545                     0.065574        0.188679
# 1               0.000000                     0.016393        0.169811
# 2               0.181818                     0.229508        0.377358
# 3               0.204545                     0.426230        0.849057
# 4               0.829545                     1.000000        1.000000
#
#    Travel & Transport
# 0            0.021053
# 1            0.073684
# 2            0.052632
# 3            0.284211
# 4            0.936842

# %%
plt.figure(figsize=(20, 10))
#plt.xticks(rotation='vertical')
sns.boxplot

ax = sns.boxplot(data = cluster_df)
ax.set_ylabel('Count of venues (relative)', fontsize=20)
ax.set_xlabel('Venue category', fontsize=20)
ax.tick_params(labelsize=20)
plt.xticks(rotation=45, ha='right')

plt.show()

# %% [markdown]
# ## Clustering

# %% [markdown]
# Let's use Elbow method to find the optimal number of clusters

# %%
cluster_df.head()
# Out:
#    Arts & Entertainment  College & University      Food  Nightlife Spot  \
# 0              0.081633              0.104478  0.013158        0.056818
# 1              0.061224              0.044776  0.021930        0.045455
# 2              0.102041              0.074627  0.144737        0.181818
# 3              0.265306              0.119403  0.197368        0.056818
# 4              1.000000              0.402985  0.991228        1.000000
#
#    Outdoors & Recreation  Professional & Other Places  Shop & Service  \
# 0               0.079545                     0.065574        0.188679
# 1               0.000000                     0.016393        0.169811
# 2               0.181818                     0.229508        0.377358
# 3               0.204545                     0.426230        0.849057
# 4               0.829545                     1.000000        1.000000
#
#    Travel & Transport
# 0            0.021053
# 1            0.073684
# 2            0.052632
# 3            0.284211
# 4            0.936842

# %%
from sklearn.cluster import KMeans
wss = []
for i in range(1,10):
    fitx = KMeans(n_clusters=i).fit(cluster_df)
    wss.append(fitx.inertia_)

plt.figure(figsize=(11,8.5))
plt.plot(range(1,10), wss, 'bx-')
plt.xlabel('Number of clusters $k$')
plt.ylabel('Inertia')
plt.title('The Elbow Method showing the optimal $k$')
plt.show()

# %% [markdown]
# So, optimal number of clusters based on 'Elbow method' is 3 for our dataframe. Note that, the elbow method is sometimes ambiguous. An alternative is the average silhouette method (Kaufman and Rousseeuw, 1990) which can be also used with any clustering approach.
# Let's try to use different approach to find optimal number of clusters - Silhouette method. The Silhouette Score reaches its global maximum at the optimal k.

# %%
import numpy as np
from sklearn.metrics import silhouette_score

scores = [0]
for i in range(2,10):
    fitx = KMeans(n_clusters=i).fit(cluster_df)
    score = silhouette_score(cluster_df, fitx.labels_)
    scores.append(score)
    
plt.figure(figsize=(11,8.5))
plt.plot(range(1,10), np.array(scores), 'bx-')
plt.xlabel('Number of clusters $k$')
plt.ylabel('Average Silhouette')
plt.title('The Elbow Method showing the optimal $k$')
plt.show()

# %% [markdown]
# The Silhouette method shows, that 2 is optimal choice for number of clusters. However observation and analysis showed that 2 is not enough, so we are going to use value - 3.

# %%
# set number of clusters
kclusters = 3

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(cluster_df)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]

# add clustering labels
cluster_labels = 'Cluster Labels'
if cluster_labels in cluster_df:
    cluster_df.drop(columns=[cluster_labels],inplace=True)
    
cluster_df.insert(0, cluster_labels, kmeans.labels_)

cluster_df.head(5)
# Out:
#    Cluster Labels  Arts & Entertainment  College & University      Food  \
# 0               0              0.081633              0.104478  0.013158
# 1               0              0.061224              0.044776  0.021930
# 2               0              0.102041              0.074627  0.144737
# 3               2              0.265306              0.119403  0.197368
# 4               1              1.000000              0.402985  0.991228
#
#    Nightlife Spot  Outdoors & Recreation  Professional & Other Places  \
# 0        0.056818               0.079545                     0.065574
# 1        0.045455               0.000000                     0.016393
# 2        0.181818               0.181818                     0.229508
# 3        0.056818               0.204545                     0.426230
# 4        1.000000               0.829545                     1.000000
#
#    Shop & Service  Travel & Transport
# 0        0.188679            0.021053
# 1        0.169811            0.073684
# 2        0.377358            0.052632
# 3        0.849057            0.284211
# 4        1.000000            0.936842

# %%
clustered_df = pd.merge(df, cluster_df, right_index=True, left_index=True)
clustered_df.head(5)
# Out:
#                         Station Opened         Type Line   Latitude  \
# 0                  Alessandrino   2014  underground    C  41.871349
# 1                      Anagnina   1980  underground    A  41.842778
# 2            Arco di Travertino   1980  underground    A  41.866705
# 3            Baldo degli Ubaldi   2000  underground    A  41.898889
# 4  Barberini - Fontana di Trevi   1980  underground    A  41.903889
#
#    Longitude  Cluster Labels  Arts & Entertainment  College & University  \
# 0  12.578701               0              0.081633              0.104478
# 1  12.586111               0              0.061224              0.044776
# 2  12.535070               0              0.102041              0.074627
# 3  12.432778               2              0.265306              0.119403
# 4  12.488889               1              1.000000              0.402985
#
#        Food  Nightlife Spot  Outdoors & Recreation  \
# 0  0.013158        0.056818               0.079545
# 1  0.021930        0.045455               0.000000
# 2  0.144737        0.181818               0.181818
# 3  0.197368        0.056818               0.204545
# 4  0.991228        1.000000               0.829545
#
#    Professional & Other Places  Shop & Service  Travel & Transport
# 0                     0.065574        0.188679            0.021053
# 1                     0.016393        0.169811            0.073684
# 2                     0.229508        0.377358            0.052632
# 3                     0.426230        0.849057            0.284211
# 4                     1.000000        1.000000            0.936842

# %%
import matplotlib.ticker as ticker

fig, axes = plt.subplots(1,kclusters, figsize=(20, 10), sharey=True)
axes[0].set_ylabel('Count of venues (relative)', fontsize=25)

for k in range(kclusters):
    #Set same y axis limits
    axes[k].set_ylim(0,1.1)
    axes[k].xaxis.set_label_position('top')
    axes[k].set_xlabel('Cluster ' + str(k), fontsize=25)
    axes[k].tick_params(labelsize=20)
    plt.sca(axes[k])
    plt.xticks(rotation='vertical')
    sns.boxplot(data = clustered_df[clustered_df['Cluster Labels']==k].drop('Cluster Labels',1), ax=axes[k])

plt.show()

# %%
#create map of Rome with all stations
map_rome_metro = folium.Map(location=[latitude, longitude], zoom_start=12)

#add markers
for i, station, latitude, longitude, cluster in zip(clustered_df.index,
                                         clustered_df['Station'],
                                         clustered_df['Latitude'],
                                         clustered_df['Longitude'],
                                         clustered_df['Cluster Labels']):
    #colors = sns.color_palette(None, kclusters).as_hex()
    colors=['blue','green','orange','red']
    #Calculate top 3 categories for each station
    station_series = clustered_df.iloc[i]
    top_categories_dict = {}
    for cat in categories_list:
        top_categories_dict[cat[0]] = station_series[cat[0]]
    top_categories = sorted(top_categories_dict.items(), key = lambda x: x[1], reverse=True)
    popup='<b>{}</b><br>Cluster {}<br>1. {} {}<br>2. {} {}<br>3. {} {}'.format(
        station,
        cluster,
        top_categories[0][0],
        "{0:.2f}".format(top_categories[0][1]),
        top_categories[1][0],
        "{0:.2f}".format(top_categories[1][1]),
        top_categories[2][0],
        "{0:.2f}".format(top_categories[2][1]))
    folium.CircleMarker(
        [latitude,longitude],
        fill=True,
        fill_opacity=0.5,
        popup=folium.Popup(popup, max_width = 300),
        radius=5,
        color=colors[cluster]
    ).add_to(map_rome_metro)
    
#add lines A
folium.PolyLine(draw_lines(line_a), color=color_A, weight=2.5, opacity=1).add_to(map_rome_metro)   
#add lines B left
folium.PolyLine(draw_lines(line_b_left), color=color_B, weight=2.5, opacity=1).add_to(map_rome_metro)   
#add lines B right
folium.PolyLine(draw_lines(line_b_right), color=color_B, weight=2.5, opacity=1).add_to(map_rome_metro)
#add lines C right
folium.PolyLine(draw_lines(line_c), color=color_C, weight=2.5, opacity=1).add_to(map_rome_metro)
    
map_rome_metro
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
clustered_df.head(5)
# Out:
#                         Station Opened         Type Line   Latitude  \
# 0                  Alessandrino   2014  underground    C  41.871349
# 1                      Anagnina   1980  underground    A  41.842778
# 2            Arco di Travertino   1980  underground    A  41.866705
# 3            Baldo degli Ubaldi   2000  underground    A  41.898889
# 4  Barberini - Fontana di Trevi   1980  underground    A  41.903889
#
#    Longitude  Cluster Labels  Arts & Entertainment  College & University  \
# 0  12.578701               0              0.081633              0.104478
# 1  12.586111               0              0.061224              0.044776
# 2  12.535070               0              0.102041              0.074627
# 3  12.432778               2              0.265306              0.119403
# 4  12.488889               1              1.000000              0.402985
#
#        Food  Nightlife Spot  Outdoors & Recreation  \
# 0  0.013158        0.056818               0.079545
# 1  0.021930        0.045455               0.000000
# 2  0.144737        0.181818               0.181818
# 3  0.197368        0.056818               0.204545
# 4  0.991228        1.000000               0.829545
#
#    Professional & Other Places  Shop & Service  Travel & Transport
# 0                     0.065574        0.188679            0.021053
# 1                     0.016393        0.169811            0.073684
# 2                     0.229508        0.377358            0.052632
# 3                     0.426230        0.849057            0.284211
# 4                     1.000000        1.000000            0.936842

# %%
#get top 3 categories for a station
def getTopCategories(dataset):
    c=['Max1','Max2','Max3']
    dataset_max=(dataset[['Arts & Entertainment','College & University','Food','Nightlife Spot','Outdoors & Recreation','Professional & Other Places','Shop & Service','Travel & Transport']]
                     .apply(lambda x: pd.Series(x.nlargest(3).index,index=c),axis=1))
    dataset_max = pd.merge(dataset[['Station']], dataset_max,right_index=True, left_index=True)
    return dataset_max

# %%
# Cluster 1
cluster1_df = clustered_df.loc[clustered_df['Cluster Labels'] == 0, clustered_df.columns[[0] + list(range(5, clustered_df.shape[1]))]]
cluster1_df
# Out:
#                       Station  Longitude  Cluster Labels  \
# 0                Alessandrino  12.578701               0
# 1                    Anagnina  12.586111               0
# 2          Arco di Travertino  12.535070               0
# 6                  Battistini  12.414722               0
# 8                  Bolognetta  12.680883               0
# 9                 Borghesiana  12.667300               0
# 12                  Cinecittà  12.574377               0
# 17                Conca d'Oro  12.527778               0
# 19  Due Leoni-Fontana Candida  12.658093               0
# 23                  Finocchio  12.687809               0
# 27                   Gardenie  12.561700               0
# 28                Giardinetti  12.610113               0
# 30                    Graniti  12.698020               0
# 31              Grotte Celoni  12.646096               0
# 32                      Jonio  12.528056               0
# 33                 Laurentina  12.481111               0
# 41                      Mirti  12.566600               0
# 42     Monte Compatri-Pantano  12.707623               0
# 43            Monti Tiburtini  12.547778               0
# 44           Numidio Quadrato  12.552658               0
# 46        Parco di Centocelle  12.568030               0
# 47                 Pietralata  12.555000               0
# 52              Ponte Mammolo  12.565000               0
# 53     Porta Furba - Quadraro  12.548206               0
# 56                   Rebibbia  12.573056               0
# 59   Santa Maria del Soccorso  12.560833               0
# 63                      Teano  12.551311               0
# 66               Torre Angela  12.625711               0
# 67                 Torre Gaia  12.635554               0
# 68                Torre Maura  12.596878               0
# 69             Torre Spaccata  12.586600               0
# 70                  Torrenova  12.616840               0
#
#     Arts & Entertainment  College & University      Food  Nightlife Spot  \
# 0               0.081633              0.104478  0.013158        0.056818
# 1               0.061224              0.044776  0.021930        0.045455
# 2               0.102041              0.074627  0.144737        0.181818
# 6               0.081633              0.029851  0.078947        0.068182
# 8               0.000000              0.014925  0.004386        0.045455
# 9               0.000000              0.014925  0.013158        0.056818
# 12              0.061224              0.149254  0.061404        0.090909
# 17              0.102041              0.044776  0.188596        0.193182
# 19              0.000000              0.014925  0.026316        0.011364
# 23              0.000000              0.014925  0.000000        0.022727
# 27              0.224490              0.014925  0.140351        0.068182
# 28              0.040816              0.029851  0.004386        0.022727
# 30              0.000000              0.000000  0.000000        0.000000
# 31              0.000000              0.029851  0.013158        0.000000
# 32              0.000000              0.059701  0.100877        0.045455
# 33              0.102041              0.104478  0.100877        0.068182
# 41              0.265306              0.059701  0.096491        0.056818
# 42              0.000000              0.000000  0.004386        0.000000
# 43              0.081633              0.044776  0.092105        0.045455
# 44              0.061224              0.089552  0.175439        0.079545
# 46              0.224490              0.104478  0.048246        0.113636
# 47              0.102041              0.104478  0.057018        0.045455
# 52              0.102041              0.104478  0.008772        0.079545
# 53              0.081633              0.089552  0.171053        0.068182
# 56              0.102041              0.059701  0.004386        0.034091
# 59              0.061224              0.104478  0.021930        0.090909
# 63              0.061224              0.059701  0.109649        0.056818
# 66              0.061224              0.014925  0.004386        0.045455
# 67              0.040816              0.059701  0.004386        0.034091
# 68              0.020408              0.059701  0.030702        0.045455
# 69              0.061224              0.044776  0.035088        0.034091
# 70              0.040816              0.000000  0.004386        0.045455
#
#     Outdoors & Recreation  Professional & Other Places  Shop & Service  \
# 0                0.079545                     0.065574        0.188679
# 1                0.000000                     0.016393        0.169811
# 2                0.181818                     0.229508        0.377358
# 6                0.125000                     0.114754        0.301887
# 8                0.045455                     0.131148        0.433962
# 9                0.034091                     0.081967        0.150943
# 12               0.068182                     0.245902        0.396226
# 17               0.147727                     0.163934        0.377358
# 19               0.034091                     0.163934        0.037736
# 23               0.011364                     0.131148        0.415094
# 27               0.068182                     0.114754        0.471698
# 28               0.034091                     0.000000        0.094340
# 30               0.022727                     0.016393        0.169811
# 31               0.056818                     0.131148        0.056604
# 32               0.136364                     0.081967        0.264151
# 33               0.090909                     0.491803        0.150943
# 41               0.090909                     0.049180        0.320755
# 42               0.011364                     0.000000        0.000000
# 43               0.113636                     0.229508        0.264151
# 44               0.147727                     0.032787        0.566038
# 46               0.079545                     0.065574        0.169811
# 47               0.079545                     0.147541        0.245283
# 52               0.056818                     0.147541        0.075472
# 53               0.125000                     0.049180        0.358491
# 56               0.022727                     0.098361        0.000000
# 59               0.045455                     0.114754        0.150943
# 63               0.113636                     0.147541        0.471698
# 66               0.011364                     0.065574        0.188679
# 67               0.056818                     0.065574        0.113208
# 68               0.045455                     0.049180        0.132075
# 69               0.000000                     0.065574        0.264151
# 70               0.034091                     0.032787        0.075472
#
#     Travel & Transport
# 0             0.021053
# 1             0.073684
# 2             0.052632
# 6             0.073684
# 8             0.000000
# 9             0.000000
# 12            0.021053
# 17            0.094737
# 19            0.021053
# 23            0.031579
# 27            0.000000
# 28            0.010526
# 30            0.031579
# 31            0.042105
# 32            0.021053
# 33            0.073684
# 41            0.021053
# 42            0.010526
# 43            0.021053
# 44            0.042105
# 46            0.010526
# 47            0.021053
# 52            0.073684
# 53            0.052632
# 56            0.042105
# 59            0.031579
# 63            0.052632
# 66            0.010526
# 67            0.000000
# 68            0.010526
# 69            0.021053
# 70            0.000000

# %%
getTopCategories(cluster1_df)
# Out:
#                       Station                         Max1  \
# 0                Alessandrino               Shop & Service
# 1                    Anagnina               Shop & Service
# 2          Arco di Travertino               Shop & Service
# 6                  Battistini               Shop & Service
# 8                  Bolognetta               Shop & Service
# 9                 Borghesiana               Shop & Service
# 12                  Cinecittà               Shop & Service
# 17                Conca d'Oro               Shop & Service
# 19  Due Leoni-Fontana Candida  Professional & Other Places
# 23                  Finocchio               Shop & Service
# 27                   Gardenie               Shop & Service
# 28                Giardinetti               Shop & Service
# 30                    Graniti               Shop & Service
# 31              Grotte Celoni  Professional & Other Places
# 32                      Jonio               Shop & Service
# 33                 Laurentina  Professional & Other Places
# 41                      Mirti               Shop & Service
# 42     Monte Compatri-Pantano        Outdoors & Recreation
# 43            Monti Tiburtini               Shop & Service
# 44           Numidio Quadrato               Shop & Service
# 46        Parco di Centocelle         Arts & Entertainment
# 47                 Pietralata               Shop & Service
# 52              Ponte Mammolo  Professional & Other Places
# 53     Porta Furba - Quadraro               Shop & Service
# 56                   Rebibbia         Arts & Entertainment
# 59   Santa Maria del Soccorso               Shop & Service
# 63                      Teano               Shop & Service
# 66               Torre Angela               Shop & Service
# 67                 Torre Gaia               Shop & Service
# 68                Torre Maura               Shop & Service
# 69             Torre Spaccata               Shop & Service
# 70                  Torrenova               Shop & Service
#
#                            Max2                         Max3
# 0          College & University         Arts & Entertainment
# 1            Travel & Transport         Arts & Entertainment
# 2   Professional & Other Places               Nightlife Spot
# 6         Outdoors & Recreation  Professional & Other Places
# 8   Professional & Other Places               Nightlife Spot
# 9   Professional & Other Places               Nightlife Spot
# 12  Professional & Other Places         College & University
# 17               Nightlife Spot                         Food
# 19               Shop & Service        Outdoors & Recreation
# 23  Professional & Other Places           Travel & Transport
# 27         Arts & Entertainment                         Food
# 28         Arts & Entertainment        Outdoors & Recreation
# 30           Travel & Transport        Outdoors & Recreation
# 31        Outdoors & Recreation               Shop & Service
# 32        Outdoors & Recreation                         Food
# 33               Shop & Service         College & University
# 41         Arts & Entertainment                         Food
# 42           Travel & Transport                         Food
# 43  Professional & Other Places        Outdoors & Recreation
# 44                         Food        Outdoors & Recreation
# 46               Shop & Service               Nightlife Spot
# 47  Professional & Other Places         College & University
# 52         College & University         Arts & Entertainment
# 53                         Food        Outdoors & Recreation
# 56  Professional & Other Places         College & University
# 59  Professional & Other Places         College & University
# 63  Professional & Other Places        Outdoors & Recreation
# 66  Professional & Other Places         Arts & Entertainment
# 67  Professional & Other Places         College & University
# 68         College & University  Professional & Other Places
# 69  Professional & Other Places         Arts & Entertainment
# 70               Nightlife Spot         Arts & Entertainment

# %%
# Cluster 2
cluster2_df=clustered_df.loc[clustered_df['Cluster Labels'] == 1, clustered_df.columns[[0] + list(range(5, clustered_df.shape[1]))]]
cluster2_df
# Out:
#                                     Station  Longitude  Cluster Labels  \
# 4              Barberini - Fontana di Trevi  12.488889               1
# 10                          Castro Pretorio  12.505556               1
# 11                                   Cavour  12.493611               1
# 16                                 Colosseo  12.491389               1
# 24             Flaminio - Piazza del Popolo  12.475833               1
# 34                                  Lepanto  12.466111               1
# 39                                  Manzoni  12.506944               1
# 45  Ottaviano - San Pietro - Musei Vaticani  12.458056               1
# 50                              Policlinico  12.511667               1
# 57           Repubblica - Teatro dell'Opera  12.495556               1
# 61                                   Spagna  12.483056               1
# 64                                  Termini  12.500596               1
# 72                        Vittorio Emanuele  12.504167               1
#
#     Arts & Entertainment  College & University      Food  Nightlife Spot  \
# 4               1.000000              0.402985  0.991228        1.000000
# 10              0.408163              0.791045  0.513158        0.386364
# 11              0.897959              0.462687  0.175439        0.375000
# 16              0.714286              0.328358  0.736842        0.670455
# 24              0.571429              0.313433  0.565789        0.488636
# 34              0.530612              0.402985  0.877193        0.545455
# 39              0.408163              0.208955  0.679825        0.545455
# 45              1.000000              0.358209  0.548246        0.409091
# 50              0.306122              1.000000  0.469298        0.284091
# 57              0.591837              0.432836  1.000000        0.863636
# 61              0.877551              0.328358  0.710526        0.863636
# 64              0.408163              0.447761  0.824561        0.556818
# 72              0.591837              0.388060  0.745614        0.772727
#
#     Outdoors & Recreation  Professional & Other Places  Shop & Service  \
# 4                0.829545                     1.000000        1.000000
# 10               0.477273                     0.721311        0.886792
# 11               0.715909                     0.803279        0.811321
# 16               0.659091                     0.737705        0.566038
# 24               0.556818                     0.557377        0.905660
# 34               0.431818                     0.475410        0.660377
# 39               0.352273                     0.557377        0.584906
# 45               0.397727                     0.590164        0.716981
# 50               0.375000                     0.557377        0.377358
# 57               0.659091                     0.901639        0.830189
# 61               1.000000                     0.868852        0.849057
# 64               0.488636                     0.868852        0.905660
# 72               0.409091                     0.655738        0.754717
#
#     Travel & Transport
# 4             0.936842
# 10            0.884211
# 11            0.694737
# 16            0.652632
# 24            0.684211
# 34            0.505263
# 39            0.400000
# 45            0.452632
# 50            0.652632
# 57            1.000000
# 61            0.705263
# 64            0.947368
# 72            0.757895

# %%
getTopCategories(cluster2_df)
# Out:
#                                     Station                         Max1  \
# 4              Barberini - Fontana di Trevi               Nightlife Spot
# 10                          Castro Pretorio               Shop & Service
# 11                                   Cavour         Arts & Entertainment
# 16                                 Colosseo  Professional & Other Places
# 24             Flaminio - Piazza del Popolo               Shop & Service
# 34                                  Lepanto                         Food
# 39                                  Manzoni                         Food
# 45  Ottaviano - San Pietro - Musei Vaticani         Arts & Entertainment
# 50                              Policlinico         College & University
# 57           Repubblica - Teatro dell'Opera                         Food
# 61                                   Spagna        Outdoors & Recreation
# 64                                  Termini           Travel & Transport
# 72                        Vittorio Emanuele               Nightlife Spot
#
#                            Max2                         Max3
# 4   Professional & Other Places               Shop & Service
# 10           Travel & Transport         College & University
# 11               Shop & Service  Professional & Other Places
# 16                         Food         Arts & Entertainment
# 24           Travel & Transport         Arts & Entertainment
# 34               Shop & Service               Nightlife Spot
# 39               Shop & Service  Professional & Other Places
# 45               Shop & Service  Professional & Other Places
# 50           Travel & Transport  Professional & Other Places
# 57           Travel & Transport  Professional & Other Places
# 61         Arts & Entertainment  Professional & Other Places
# 64               Shop & Service  Professional & Other Places
# 72           Travel & Transport               Shop & Service

# %%
# Cluster 3
cluster3_df=clustered_df.loc[clustered_df['Cluster Labels'] == 2, clustered_df.columns[[0] + list(range(5, clustered_df.shape[1]))]]
cluster3_df
# Out:
#                       Station  Longitude  Cluster Labels  \
# 3          Baldo degli Ubaldi  12.432778               2
# 5          Basilica San Paolo  12.478194               2
# 7                     Bologna  12.520556               2
# 13                      Cipro  12.447500               2
# 14              Circo Massimo  12.488056               2
# 15               Colli Albani  12.530100               2
# 18                   Cornelia  12.425278               2
# 20                  EUR Fermi  12.471111               2
# 21               EUR Magliana  12.463333               2
# 22              EUR Palasport  12.466667               2
# 25              Furio Camillo  12.523056               2
# 26                 Garbatella  12.483333               2
# 29            Giulio Agricola  12.562633               2
# 35                      Libia  12.520556               2
# 36                       Lodi  12.517762               2
# 37               Lucio Sestio  12.557283               2
# 38                  Malatesta  12.540200               2
# 40                    Marconi  12.475556               2
# 48                    Pigneto  12.528178               2
# 49                   Piramide  12.482222               2
# 51                Ponte Lungo  12.518957               2
# 54                Quintiliani  12.538611               2
# 55                 Re di Roma  12.514405               2
# 58               San Giovanni  12.509444               2
# 60  Sant Agnese - Annibaliano  12.515833               2
# 62                 Subaugusta  12.567701               2
# 65                  Tiburtina  12.529444               2
# 71              Valle Aurelia  12.441667               2
#
#     Arts & Entertainment  College & University      Food  Nightlife Spot  \
# 3               0.265306              0.119403  0.197368        0.056818
# 5               0.183673              0.447761  0.267544        0.193182
# 7               0.204082              0.417910  0.153509        0.204545
# 13              0.816327              0.044776  0.403509        0.238636
# 14              0.183673              0.074627  0.451754        0.386364
# 15              0.122449              0.074627  0.206140        0.250000
# 18              0.285714              0.074627  0.118421        0.068182
# 20              0.163265              0.119403  0.245614        0.147727
# 21              0.102041              0.044776  0.157895        0.170455
# 22              0.163265              0.059701  0.210526        0.136364
# 25              0.142857              0.104478  0.263158        0.238636
# 26              0.306122              0.149254  0.320175        0.363636
# 29              0.081633              0.179104  0.175439        0.090909
# 35              0.081633              0.059701  0.127193        0.136364
# 36              0.265306              0.149254  0.412281        0.431818
# 37              0.081633              0.089552  0.232456        0.079545
# 38              0.122449              0.044776  0.250000        0.238636
# 40              0.081633              0.313433  0.232456        0.113636
# 48              0.122449              0.044776  0.263158        0.420455
# 49              0.367347              0.104478  0.469298        0.363636
# 51              0.122449              0.089552  0.377193        0.238636
# 54              0.020408              0.014925  0.171053        0.079545
# 55              0.102041              0.134328  0.416667        0.250000
# 58              0.265306              0.223881  0.521930        0.261364
# 60              0.122449              0.223881  0.254386        0.295455
# 62              0.061224              0.044776  0.153509        0.068182
# 65              0.081633              0.089552  0.232456        0.261364
# 71              0.102041              0.029851  0.271930        0.068182
#
#     Outdoors & Recreation  Professional & Other Places  Shop & Service  \
# 3                0.204545                     0.426230        0.849057
# 5                0.238636                     0.442623        0.339623
# 7                0.261364                     0.327869        0.509434
# 13               0.238636                     0.475410        0.641509
# 14               0.454545                     0.852459        0.245283
# 15               0.227273                     0.360656        0.452830
# 18               0.147727                     0.377049        0.603774
# 20               0.159091                     0.688525        0.320755
# 21               0.170455                     0.524590        0.301887
# 22               0.147727                     0.606557        0.339623
# 25               0.329545                     0.393443        0.490566
# 26               0.136364                     0.377049        0.358491
# 29               0.159091                     0.262295        0.716981
# 35               0.193182                     0.360656        0.622642
# 36               0.215909                     0.278689        0.641509
# 37               0.181818                     0.147541        0.584906
# 38               0.159091                     0.262295        0.452830
# 40               0.215909                     0.262295        0.339623
# 48               0.227273                     0.245902        0.433962
# 49               0.193182                     0.540984        0.509434
# 51               0.318182                     0.409836        0.679245
# 54               0.113636                     0.278689        0.490566
# 55               0.363636                     0.344262        0.773585
# 58               0.284091                     0.491803        0.811321
# 60               0.250000                     0.344262        0.490566
# 62               0.136364                     0.344262        0.716981
# 65               0.147727                     0.229508        0.547170
# 71               0.193182                     0.377049        0.490566
#
#     Travel & Transport
# 3             0.284211
# 5             0.052632
# 7             0.652632
# 13            0.410526
# 14            0.421053
# 15            0.084211
# 18            0.168421
# 20            0.094737
# 21            0.031579
# 22            0.052632
# 25            0.157895
# 26            0.221053
# 29            0.031579
# 35            0.084211
# 36            0.463158
# 37            0.073684
# 38            0.126316
# 40            0.084211
# 48            0.221053
# 49            0.273684
# 51            0.263158
# 54            0.147368
# 55            0.273684
# 58            0.378947
# 60            0.147368
# 62            0.031579
# 65            0.442105
# 71            0.347368

# %%
getTopCategories(cluster3_df)
# Out:
#                       Station                         Max1  \
# 3          Baldo degli Ubaldi               Shop & Service
# 5          Basilica San Paolo         College & University
# 7                     Bologna           Travel & Transport
# 13                      Cipro         Arts & Entertainment
# 14              Circo Massimo  Professional & Other Places
# 15               Colli Albani               Shop & Service
# 18                   Cornelia               Shop & Service
# 20                  EUR Fermi  Professional & Other Places
# 21               EUR Magliana  Professional & Other Places
# 22              EUR Palasport  Professional & Other Places
# 25              Furio Camillo               Shop & Service
# 26                 Garbatella  Professional & Other Places
# 29            Giulio Agricola               Shop & Service
# 35                      Libia               Shop & Service
# 36                       Lodi               Shop & Service
# 37               Lucio Sestio               Shop & Service
# 38                  Malatesta               Shop & Service
# 40                    Marconi               Shop & Service
# 48                    Pigneto               Shop & Service
# 49                   Piramide  Professional & Other Places
# 51                Ponte Lungo               Shop & Service
# 54                Quintiliani               Shop & Service
# 55                 Re di Roma               Shop & Service
# 58               San Giovanni               Shop & Service
# 60  Sant Agnese - Annibaliano               Shop & Service
# 62                 Subaugusta               Shop & Service
# 65                  Tiburtina               Shop & Service
# 71              Valle Aurelia               Shop & Service
#
#                            Max2                         Max3
# 3   Professional & Other Places           Travel & Transport
# 5   Professional & Other Places               Shop & Service
# 7                Shop & Service         College & University
# 13               Shop & Service  Professional & Other Places
# 14        Outdoors & Recreation                         Food
# 15  Professional & Other Places               Nightlife Spot
# 18  Professional & Other Places         Arts & Entertainment
# 20               Shop & Service                         Food
# 21               Shop & Service               Nightlife Spot
# 22               Shop & Service                         Food
# 25  Professional & Other Places        Outdoors & Recreation
# 26               Nightlife Spot               Shop & Service
# 29  Professional & Other Places         College & University
# 35  Professional & Other Places        Outdoors & Recreation
# 36           Travel & Transport               Nightlife Spot
# 37                         Food        Outdoors & Recreation
# 38  Professional & Other Places                         Food
# 40         College & University  Professional & Other Places
# 48               Nightlife Spot                         Food
# 49               Shop & Service                         Food
# 51  Professional & Other Places                         Food
# 54  Professional & Other Places                         Food
# 55                         Food        Outdoors & Recreation
# 58                         Food  Professional & Other Places
# 60  Professional & Other Places               Nightlife Spot
# 62  Professional & Other Places                         Food
# 65           Travel & Transport               Nightlife Spot
# 71  Professional & Other Places           Travel & Transport
